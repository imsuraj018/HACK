# %%
import json

recommendations = {
  "bacterial_blight": {
    "description": {
      "en": "Bacterial Blight is a common bacterial disease in cotton causing leaf spots and wilting.",
      "hi": "बैक्टीरियल ब्लाइट कपास में एक सामान्य बैक्टीरियल रोग है जो पत्तियों पर धब्बे और मुरझाने का कारण बनता है।",
      "mr": "बॅक्टेरियल ब्लाईट ही कापूसमधील एक सामान्य बॅक्टेरियल रोग आहे जी पाने पिवळी व मुरझवते."
    },
    "sprays": {
      "en": ["Copper Oxychloride 0.3%", "Streptomycin 0.05%"],
      "hi": ["कॉपर ऑक्सीक्लोराइड 0.3%", "स्ट्रेप्टोमाइसिन 0.05%"],
      "mr": ["कॉपर ऑक्सीक्लोराइड 0.3%", "स्ट्रेप्टोमायसिन 0.05%"]
    },
    "fertilizers": {
      "en": ["Nitrogen 20kg/acre", "Potassium 10kg/acre"],
      "hi": ["नाइट्रोजन 20 किग्रा/एकर", "पोटॅशियम 10 किग्रा/एकर"],
      "mr": ["नायट्रोजन 20 किग्रॅ/एकर", "पोटॅशियम 10 किग्रॅ/एकर"]
    },
    "notes": {
      "en": "Spray early in morning or late evening. Ensure good field drainage.",
      "hi": "सुबह जल्दी या शाम को छिड़काव करें। खेत में अच्छी जल निकासी सुनिश्चित करें।",
      "mr": "सकाळी लवकर किंवा संध्याकाळी फवारणी करा. क्षेत्राची चांगली पाणी निकासी सुनिश्चित करा."
    }
  },

  "curl_virus": {
    "description": {
      "en": "Cotton Leaf Curl Virus causes leaf curling and stunted growth.",
      "hi": "कॉटन लीफ कर्ल वायरस पत्तियों को मुड़ने और विकास को बाधित करने का कारण बनता है।",
      "mr": "कापूस लीफ कर्ल व्हायरस पाने वळवतो आणि वाढ मंद करतो."
    },
    "sprays": {
      "en": ["Imidacloprid 0.3%", "Thiamethoxam 0.25%"],
      "hi": ["इमिडाक्लोप्रिड 0.3%", "थायमेटॉक्सॅम 0.25%"],
      "mr": ["इमिडाक्लोप्रिड 0.3%", "थायमेटॉक्सॅम 0.25%"]
    },
    "fertilizers": {
      "en": ["Balanced NPK 20:20:20 10kg/acre"],
      "hi": ["संतुलित NPK 20:20:20 10 किग्रा/एकर"],
      "mr": ["संतुलित NPK 20:20:20 10 किग्रॅ/एकर"]
    },
    "notes": {
      "en": "Control whiteflies; remove infected plants.",
      "hi": "सफेद मक्खियों को नियंत्रित करें; संक्रमित पौधों को हटा दें।",
      "mr": "व्हाइटफ्लाय नियंत्रित करा; संक्रमित रोपे काढा."
    }
  },

  "fussarium_wilt": {
    "description": {
      "en": "Fusarium Wilt is a soil-borne fungal disease causing wilting of plants.",
      "hi": "फ्यूजेरियम वील्ट मिट्टी से फैलने वाला एक कवक रोग है जो पौधों को मुरझा देता है।",
      "mr": "फ्यूझेरियम विल्ट ही मातीमध्ये फैलणारी बुरशी रोग आहे जी रोपे मुरझवते."
    },
    "sprays": {
      "en": ["Carbendazim 0.1%", "Trichoderma viride biofungicide"],
      "hi": ["कार्बेन्डाझिम 0.1%", "ट्राइकोडर्मा विराइड बायोफंजीसाइड"],
      "mr": ["कार्बेन्डाझिम 0.1%", "ट्रायकोडर्मा विरिड बायोफंजीसाइड"]
    },
    "fertilizers": {
      "en": ["Phosphorus 15kg/acre", "Potassium 10kg/acre"],
      "hi": ["फॉस्फोरस 15 किग्रा/एकर", "पोटॅशियम 10 किग्रा/एकर"],
      "mr": ["फॉस्फरस 15 किग्रॅ/एकर", "पोटॅशियम 10 किग्रॅ/एकर"]
    },
    "notes": {
      "en": "Use resistant varieties; crop rotation helps.",
      "hi": "प्रतिरोधी किस्में उपयोग करें; फसल घुमाव मदद करता है।",
      "mr": "प्रतिरोधक प्रजाती वापरा; पीक फेरफार उपयुक्त आहे."
    }
  },

  "healthy": {
    "description": {
      "en": "No disease detected. The plant is healthy.",
      "hi": "कोई रोग नहीं पाया गया। पौधा स्वस्थ है।",
      "mr": "कोणताही रोग नाही. रोप निरोगी आहे."
    },
    "sprays": {"en": [], "hi": [], "mr": []},
    "fertilizers": {
      "en": ["Balanced NPK 20:20:20 10kg/acre"],
      "hi": ["संतुलित NPK 20:20:20 10 किग्रा/एकर"],
      "mr": ["संतुलित NPK 20:20:20 10 किग्रॅ/एकर"]
    },
    "notes": {
      "en": "Maintain proper irrigation and nutrition.",
      "hi": "सही सिंचाई और पोषण बनाए रखें।",
      "mr": "योग्य पाणी देणे आणि खत देणे सुनिश्चित करा."
    }
  }
}

# Save JSON file
with open("Cotton_disease_recommendations1.json", "w", encoding="utf-8") as f:
    json.dump(recommendations, f, indent=4, ensure_ascii=False)

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import json

# -------------------------
# Load trained model
# -------------------------
model = load_model("custom_cotton_cnn.h5")

# Classes in the same order as your training dataset
class_labels = ["bacterial_blight", "curl_virus", "fussarium_wilt", "healthy"]

# -------------------------
# Function to preprocess and predict a single image
# -------------------------
def predict_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224)) 
    img_array = image.img_to_array(img) / 255.0            
    img_array = np.expand_dims(img_array, axis=0)         

    preds = model.predict(img_array, verbose=0)
    predicted_class = class_labels[np.argmax(preds)]
    confidence = np.max(preds)

    return predicted_class, confidence
# Out:
# 2025-09-23 17:25:02.437012: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 17:25:02.468009: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/sk/miniconda3/lib/python3.13/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ...

# %%
import json

# Load recommendations JSON
with open("Cotton_disease_recommendations1.json", "r") as f:
    recommendations = json.load(f)

# Predict image
img_path = "/home/sk/Desktop/crop_disease_dataset/archive(2)/cotton/curl_virus/curl15.jpg"
pred_class, conf = predict_image(img_path)


# Get recommendation
rec = recommendations.get(pred_class, {})
for lang, lang_name in zip(['en','hi','mr'], ['English','Hindi','Marathi']):
    print(f"--- {lang_name} ---")
    print(f"Description: {rec.get('description', {}).get(lang,'')}")
    sprays = ', '.join(rec.get('sprays', {}).get(lang,[]))
    print(f"Sprays: {sprays if sprays else 'None'}")
    fertilizers = ', '.join(rec.get('fertilizers', {}).get(lang,[]))
    print(f"Fertilizers: {fertilizers if fertilizers else 'None'}")
    print(f"Notes: {rec.get('notes', {}).get(lang,'')}\n")
# Out:
# 2025-09-23 17:25:08.773966: I external/local_xla/xla/service/service.cc:163] XLA service 0x7462c00039a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-23 17:25:08.773988: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA T400 4GB, Compute Capability 7.5
# 2025-09-23 17:25:08.778632: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-23 17:25:08.813986: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# --- English ---
# Description: Cotton Leaf Curl Virus causes leaf curling and stunted growth.
# Sprays: Imidacloprid 0.3%, Thiamethoxam 0.25%
# Fertilizers: Balanced NPK 20:20:20 10kg/acre
# Notes: Control whiteflies; remove infected plants.
#
# --- Hindi ---
# ...
